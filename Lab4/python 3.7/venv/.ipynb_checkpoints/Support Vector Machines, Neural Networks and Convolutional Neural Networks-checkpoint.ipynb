# %% [markdown]
# # Lab 4: Support Vector Machines, Neural Networks and Convolutional Neural Networks
#
# Using 13D Wine Dataset

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.7

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import tensorflow as tf

# %% [markdown]
# # Load Data

# %%
wineData = np.load('wineData.npy')
wineLabels = np.load('wineLabels.npy')

# %%
plt.scatter(wineData[:,0], wineData[:,1], c=wineLabels)

# Add title and axis names
plt.title('Wine data')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')


plt.show()

# %% [markdown]
# Split data into testing and training 80-20 split

# %%
#wineData, wineLabels = shuffle(wineData, wineLabels, random_state=0) #make sure the samples are not ordered
xTrn, xTst, yTrn, yTst = train_test_split(wineData, wineLabels, test_size=0.2)

# %%
print(xTst)
# Out:
# [[1.225e+01 3.880e+00 2.200e+00 1.850e+01 1.120e+02 1.380e+00 7.800e-01
#   2.900e-01 1.140e+00 8.210e+00 6.500e-01 2.000e+00 8.550e+02]
#  [1.277e+01 3.430e+00 1.980e+00 1.600e+01 8.000e+01 1.630e+00 1.250e+00
#   4.300e-01 8.300e-01 3.400e+00 7.000e-01 2.120e+00 3.720e+02]
#  [1.270e+01 3.870e+00 2.400e+00 2.300e+01 1.010e+02 2.830e+00 2.550e+00
#   4.300e-01 1.950e+00 2.570e+00 1.190e+00 3.130e+00 4.630e+02]
#  [1.221e+01 1.190e+00 1.750e+00 1.680e+01 1.510e+02 1.850e+00 1.280e+00
#   1.400e-01 2.500e+00 2.850e+00 1.280e+00 3.070e+00 7.180e+02]
#  [1.222e+01 1.290e+00 1.940e+00 1.900e+01 9.200e+01 2.360e+00 2.040e+00
#   3.900e-01 2.080e+00 2.700e+00 8.600e-01 3.020e+00 3.120e+02]
#  [1.437e+01 1.950e+00 2.500e+00 1.680e+01 1.130e+02 3.850e+00 3.490e+00
#   2.400e-01 2.180e+00 7.800e+00 8.600e-01 3.450e+00 1.480e+03]
#  [1.378e+01 2.760e+00 2.300e+00 2.200e+01 9.000e+01 1.350e+00 6.800e-01
#   4.100e-01 1.030e+00 9.580e+00 7.000e-01 1.680e+00 6.150e+02]
#  [1.279e+01 2.670e+00 2.480e+00 2.200e+01 1.120e+02 1.480e+00 1.360e+00
#   2.400e-01 1.260e+00 1.080e+01 4.800e-01 1.470e+00 4.800e+02]
#  [1.422e+01 1.700e+00 2.300e+00 1.630e+01 1.180e+02 3.200e+00 3.000e+00
#   2.600e-01 2.030e+00 6.380e+00 9.400e-01 3.310e+00 9.700e+02]
#  [1.242e+01 2.550e+00 2.270e+00 2.200e+01 9.000e+01 1.680e+00 1.840e+00
#   6.600e-01 1.420e+00 2.700e+00 8.600e-01 3.300e+00 3.150e+02]
#  [1.329e+01 1.970e+00 2.680e+00 1.680e+01 1.020e+02 3.000e+00 3.230e+00
#   3.100e-01 1.660e+00 6.000e+00 1.070e+00 2.840e+00 1.270e+03]
#  [1.299e+01 1.670e+00 2.600e+00 3.000e+01 1.390e+02 3.300e+00 2.890e+00
#   2.100e-01 1.960e+00 3.350e+00 1.310e+00 3.500e+00 9.850e+02]

#  [1.356e+01 1.710e+00 2.310e+00 1.620e+01 1.170e+02 3.150e+00 3.290e+00
#   3.400e-01 2.340e+00 6.130e+00 9.500e-01 3.380e+00 7.950e+02]
#  [1.369e+01 3.260e+00 2.540e+00 2.000e+01 1.070e+02 1.830e+00 5.600e-01
#   5.000e-01 8.000e-01 5.880e+00 9.600e-01 1.820e+00 6.800e+02]
#  [1.245e+01 3.030e+00 2.640e+00 2.700e+01 9.700e+01 1.900e+00 5.800e-01
#   6.300e-01 1.140e+00 7.500e+00 6.700e-01 1.730e+00 8.800e+02]
#  [1.367e+01 1.250e+00 1.920e+00 1.800e+01 9.400e+01 2.100e+00 1.790e+00
#   3.200e-01 7.300e-01 3.800e+00 1.230e+00 2.460e+00 6.300e+02]]

# %%
plt.scatter(wineData[:,0], wineData[:,1], c=wineLabels)

# Add title and axis names
plt.title('Wine data')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')
plt.show()

# %% [markdown]
# # Plot showing test/train split

# %%
plt.figure()

plt.scatter(xTrn[:,0], xTrn[:,1], c=yTrn, marker="o")
plt.scatter(xTst[:,0], xTst[:,1], c=yTst, marker='v')
# Add title and axis names
plt.title('Checking consistent data and labels')
plt.xlabel('Alcohol')
plt.ylabel('Malic Acid')


plt.show()

# %% [markdown]
# # Task 4.1 - Multiclass SVM for Wine Data

# %% [markdown]
# ### Use standardScalr to standardise the class

# %%
normaliser = StandardScaler()
XTrn = normaliser.fit_transform(xTrn)
XTst = normaliser.transform(xTst)

# %%
print(XTrn)
# Out:
# [[-1.41701927e+00 -1.60031623e-01  1.40712663e+00 ... -7.62123731e-02
#   -5.01616782e-01 -3.83945166e-01]
#  [-5.79861973e-01 -5.04074763e-01 -1.40400084e+00 ...  3.17161669e-01
#    1.35457486e+00 -2.35276679e-01]
#  [-8.90806114e-01 -5.04074763e-01 -8.86161569e-01 ...  1.42328761e-01
#    7.87798785e-01 -7.47708485e-01]
#  ...
#  [ 6.59450872e-02  1.37493008e+00 -1.46391182e-01 ... -5.57002869e-01
#   -8.55851828e-01 -7.31892689e-01]
#  [ 8.55264828e-01 -3.89393716e-01  1.56289518e-03 ...  6.23119257e-01
#    1.96385914e+00  9.12950145e-01]
#  [ 1.13033080e+00 -5.04074763e-01 -3.31333779e-01 ...  6.66827484e-01
#    6.88612972e-01  1.62466099e+00]]

# %%
print(XTst)
# Out:
# [[-8.90806114e-01  1.39257332e+00 -5.90253414e-01 -2.33437944e-01
#    9.69573381e-01 -1.48288025e+00 -1.28850891e+00 -5.86589661e-01
#   -7.93755811e-01  1.40938511e+00 -1.38745918e+00 -8.70021230e-01
#    3.43581472e-01]
#  [-2.68917833e-01  9.95600462e-01 -1.40400084e+00 -9.97221077e-01
#   -1.34072627e+00 -1.07656465e+00 -8.04792603e-01  5.45585335e-01
#   -1.32769730e+00 -6.85173552e-01 -1.16891805e+00 -6.99988408e-01
#   -1.18422447e+00]
#  [-3.52633563e-01  1.38375170e+00  1.49516973e-01  1.14137170e+00
#    1.75407874e-01  8.73750217e-01  5.33146108e-01  5.45585335e-01
#    6.01381618e-01 -1.04660467e+00  9.72785072e-01  7.31121178e-01
#  [ 8.55264828e-01 -3.89393716e-01  1.56289518e-03 ...  6.23119257e-01
#    1.96385914e+00  9.12950145e-01]
#  [ 1.13033080e+00 -5.04074763e-01 -3.31333779e-01 ...  6.66827484e-01
#    6.88612972e-01  1.62466099e+00]]

# %%
svc.predict(XTst)
svc.score(XTst, yTst)
# Out:
# 0.9444444444444444

# %% [markdown]
# ### Visualise test data in scatter plot, colour the ground truth values and draw a scatter plot to visualise test data with predicted class values coloured

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(5, 5))

axes[0].set_title('Ground Truth')
axes[0].set_ylabel('Feature 1 Dimension - Alcohol')
axes[0].set_xlabel('Feature 0 Dimension - Malic Acid')

axes[1].set_title('Predicted Labels')

axes[0].scatter(XTst[:,0], XTst[:,1], c=yTst, marker="o")
axes[1].scatter(XTst[:,0], XTst[:,1], c=np.argmax(model.predict(XTst), axis=1), marker='v')
fig.tight_layout()

# %% [markdown]
# # 4.2 - Neural Network for Wine Data

# %%
#altered hyperparameter in layer 1 to selu
model = tf.keras.Sequential(layers=[
    tf.keras.layers.Dense(4, activation=tf.nn.selu),
    tf.keras.layers.Dense(10, activation=tf.nn.relu),
    tf.keras.layers.Dense(len(np.unique(yTrn)), activation=tf.nn.softmax)])

# %%
#hyperparameter steps_per_execution increased to 2
model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=tf.keras.metrics.SparseCategoricalAccuracy(),
              steps_per_execution=2)

# %%
history = model.fit(XTrn, yTrn, epochs=100, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 124ms/step - loss: 1.2788 - sparse_categorical_accuracy: 0.3162 - val_loss: 1.0963 - val_sparse_categorical_accuracy: 0.3448
# Epoch 2/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2233 - sparse_categorical_accuracy: 0.3840 - val_loss: 1.0685 - val_sparse_categorical_accuracy: 0.3793
# Epoch 3/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2257 - sparse_categorical_accuracy: 0.3508 - val_loss: 1.0424 - val_sparse_categorical_accuracy: 0.4483
# Epoch 4/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2332 - sparse_categorical_accuracy: 0.3374 - val_loss: 1.0172 - val_sparse_categorical_accuracy: 0.4828
# Epoch 5/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.2026 - sparse_categorical_accuracy: 0.3427 - val_loss: 0.9967 - val_sparse_categorical_accuracy: 0.4828
# Epoch 6/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1593 - sparse_categorical_accuracy: 0.3836 - val_loss: 0.9768 - val_sparse_categorical_accuracy: 0.5862
# Epoch 7/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1354 - sparse_categorical_accuracy: 0.4005 - val_loss: 0.9580 - val_sparse_categorical_accuracy: 0.6207
# Epoch 8/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1323 - sparse_categorical_accuracy: 0.4005 - val_loss: 0.9413 - val_sparse_categorical_accuracy: 0.6207
# Epoch 9/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0984 - sparse_categorical_accuracy: 0.4174 - val_loss: 0.9257 - val_sparse_categorical_accuracy: 0.6207
# Epoch 10/100
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0760 - sparse_categorical_accuracy: 0.4414 - val_loss: 0.9119 - val_sparse_categorical_accuracy: 0.6897
# Epoch 11/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0457 - sparse_categorical_accuracy: 0.4699 - val_loss: 0.8998 - val_sparse_categorical_accuracy: 0.6897
# Epoch 12/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0513 - sparse_categorical_accuracy: 0.4627 - val_loss: 0.8877 - val_sparse_categorical_accuracy: 0.6897
# Epoch 13/100
# 4/4 [==============================] - 0s 6ms/step - loss: 1.
# Epoch 38/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6456 - sparse_categorical_accuracy: 0.7932 - val_loss: 0.6227 - val_sparse_categorical_accuracy: 0.8621
# Epoch 39/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6587 - sparse_categorical_accuracy: 0.7869 - val_loss: 0.6126 - val_sparse_categorical_accuracy: 0.8621
# Epoch 40/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6173 - sparse_categorical_accuracy: 0.8163 - val_loss: 0.6025 - val_sparse_categorical_accuracy: 0.8621
# Epoch 41/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6457 - sparse_categorical_accuracy: 0.7841 - val_loss: 0.5920 - val_sparse_categorical_accuracy: 0.8621
# Epoch 42/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6305 - sparse_categorical_accuracy: 0.7904 - val_loss: 0.5831 - val_sparse_categorical_accuracy: 0.8621
# Epoch 43/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6196 - sparse_categorical_accuracy: 0.7894 - val_loss: 0.5733 - val_sparse_categorical_accuracy: 0.8621
# Epoch 44/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5937 - sparse_categorical_accuracy: 0.8144 - val_loss: 0.5635 - val_sparse_categorical_accuracy: 0.8621
# Epoch 45/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5935 - sparse_categorical_accuracy: 0.8072 - val_loss: 0.5535 - val_sparse_categorical_accuracy: 0.8621
# Epoch 46/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5842 - sparse_categorical_accuracy: 0.8135 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.8966
# Epoch 47/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5727 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.5343 - val_sparse_categorical_accuracy: 0.8966
# Epoch 48/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5732 - sparse_categorical_accuracy: 0.8251 - val_loss: 0.5254 - val_sparse_categorical_accuracy: 0.8966
# Epoch 49/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5497 - sparse_categorical_accuracy: 0.8179 - val_loss: 0.5151 - val_sparse_categorical_accuracy: 0.8966
# Epoch 50/100
# 4/4 [==============================] - ETA: 0s - loss: 0.5378 - sparse_categorical_accuracy: 0.859 - 0s 6ms/step - loss: 0.5336 - sparse_categorical_accuracy: 0.8535 - val_loss: 0.5053 - val_sparse_categorical_accuracy: 0.8966
# Epoch 51/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5267 - sparse_categorical_accuracy: 0.8588 - val_loss: 0.4950 - val_sparse_categorical_accuracy: 0.8966
# Epoch 52/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5297 - sparse_categorical_accuracy: 0.8463 - val_loss: 0.4857 - val_sparse_categorical_accuracy: 0.8966
# Epoch 53/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4815 - sparse_categorical_accuracy: 0.8766 - val_loss: 0.4768 - val_sparse_categorical_accuracy: 0.8966
# Epoch 54/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4836 - sparse_categorical_accuracy: 0.8766 - val_loss: 0.4675 - val_sparse_categorical_accuracy: 0.8966
# Epoch 55/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4825 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.4581 - val_sparse_categorical_accuracy: 0.8966
# Epoch 56/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4419 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.4491 - val_sparse_categorical_accuracy: 0.8966
# Epoch 57/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4523 - sparse_categorical_accuracy: 0.8925 - val_loss: 0.4404 - val_sparse_categorical_accuracy: 0.8966
# Epoch 58/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4553 - sparse_categorical_accuracy: 0.8916 - val_loss: 0.4315 - val_sparse_categorical_accuracy: 0.8966
# Epoch 59/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4369 - sparse_categorical_accuracy: 0.8978 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.8966
# Epoch 60/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4329 - sparse_categorical_accuracy: 0.9041 - val_loss: 0.4161 - val_sparse_categorical_accuracy: 0.8966
# Epoch 61/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4198 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.4089 - val_sparse_categorical_accuracy: 0.8966
# Epoch 62/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4091 - sparse_categorical_accuracy: 0.9147 - val_loss: 0.4013 - val_sparse_categorical_accuracy: 0.8966
# Epoch 63/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4108 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.3943 - val_sparse_categorical_accuracy: 0.8966
# Epoch 64/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3936 - sparse_categorical_accuracy: 0.9210 - val_loss: 0.3863 - val_sparse_categorical_accuracy: 0.8966
# Epoch 65/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3797 - sparse_categorical_accuracy: 0.9263 - val_loss: 0.3785 - val_sparse_categorical_accuracy: 0.8966
# Epoch 66/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3683 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.3711 - val_sparse_categorical_accuracy: 0.8966
# Epoch 67/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3721 - sparse_categorical_accuracy: 0.9200 - val_loss: 0.3638 - val_sparse_categorical_accuracy: 0.8966
# Epoch 68/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3652 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.3566 - val_sparse_categorical_accuracy: 0.8966
# Epoch 69/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3569 - sparse_categorical_accuracy: 0.9325 - val_loss: 0.3500 - val_sparse_categorical_accuracy: 0.8966
# Epoch 70/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3528 - sparse_categorical_accuracy: 0.9253 - val_loss: 0.3428 - val_sparse_categorical_accuracy: 0.8966
# Epoch 71/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3427 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.3358 - val_sparse_categorical_accuracy: 0.8966
# Epoch 72/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.8966
# Epoch 73/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3176 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.8966
# Epoch 74/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3347 - sparse_categorical_accuracy: 0.9306 - val_loss: 0.3154 - val_sparse_categorical_accuracy: 0.8966
# Epoch 75/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3186 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.3072 - val_sparse_categorical_accuracy: 0.8966
# Epoch 76/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3035 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.3012 - val_sparse_categorical_accuracy: 0.8966
# Epoch 77/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3162 - sparse_categorical_accuracy: 0.9306 - val_loss: 0.2947 - val_sparse_categorical_accuracy: 0.8966
# Epoch 78/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2847 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.2889 - val_sparse_categorical_accuracy: 0.8966
# Epoch 79/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2726 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.2834 - val_sparse_categorical_accuracy: 0.8966
# Epoch 80/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2803 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2777 - val_sparse_categorical_accuracy: 0.8966
# Epoch 81/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2727 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2728 - val_sparse_categorical_accuracy: 0.9310
# Epoch 82/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2624 - sparse_categorical_accuracy: 0.9494 - val_loss: 0.2685 - val_sparse_categorical_accuracy: 0.9310
# Epoch 83/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2522 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2632 - val_sparse_categorical_accuracy: 0.9310
# Epoch 84/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2499 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.2582 - val_sparse_categorical_accuracy: 0.9310
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2440 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.2541 - val_sparse_categorical_accuracy: 0.9310
# Epoch 86/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2578 - sparse_categorical_accuracy: 0.9369 - val_loss: 0.2488 - val_sparse_categorical_accuracy: 0.9310
# Epoch 87/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2420 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2438 - val_sparse_categorical_accuracy: 0.9310
# Epoch 88/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2322 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2397 - val_sparse_categorical_accuracy: 0.9310
# Epoch 89/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2327 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2355 - val_sparse_categorical_accuracy: 0.9310
# Epoch 90/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2275 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2323 - val_sparse_categorical_accuracy: 0.9310
# Epoch 91/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2061 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.2287 - val_sparse_categorical_accuracy: 0.9310
# Epoch 92/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2205 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2252 - val_sparse_categorical_accuracy: 0.9310
# Epoch 93/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2152 - sparse_categorical_accuracy: 0.9610 - val_loss: 0.2218 - val_sparse_categorical_accuracy: 0.9310
# Epoch 94/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2065 - sparse_categorical_accuracy: 0.9672 - val_loss: 0.2183 - val_sparse_categorical_accuracy: 0.9310
# Epoch 95/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2148 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2151 - val_sparse_categorical_accuracy: 0.9310
# Epoch 96/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2164 - sparse_categorical_accuracy: 0.9485 - val_loss: 0.2126 - val_sparse_categorical_accuracy: 0.9310
# Epoch 97/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2117 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2095 - val_sparse_categorical_accuracy: 0.9310
# Epoch 98/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2047 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2067 - val_sparse_categorical_accuracy: 0.9310
# Epoch 99/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1972 - sparse_categorical_accuracy: 0.9610 - val_loss: 0.2039 - val_sparse_categorical_accuracy: 0.9310
# Epoch 100/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1866 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.2014 - val_sparse_categorical_accuracy: 0.9310

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 4)                 56
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_14 (Dense)             (None, 3)                 33
# =================================================================
# Total params: 139
# Trainable params: 139
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %%
results = model.evaluate(XTst, yTst)

print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3180 - sparse_categorical_accuracy: 0.9444
# Test set loss: 0.32, test set accuracy: 94.44%

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.scatter(XTst[:,0], XTst[:,1], c=yTst)
plt.ylabel('Feature Dimension 1')
plt.xlabel('Feature Dimension 0')
plt.title('Ground Truth')
plt.subplot(122)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.scatter(XTst[:,0], XTst[:,1], c=np.argmax(model.predict(XTst), axis=1))
plt.show()

# %% [markdown]
# # 4.3 Neural Network for Digit Recognition

# %% [markdown]
# Load in MNIST dataset

# %%
(x_train, y_train), (x_test, y_test) = tf. keras.datasets.mnist.load_data()

# %%
print(f'MNIST sample shape: {x_train.shape[1:]}')
print(f'Number of training samples: {x_train.shape[0]}')
print(f'Number of testing samples: {x_test.shape[0]}')
print(f'Number of classes: {len(np.unique(y_train))}')
# Out:
# MNIST sample shape: (28, 28)
# Number of training samples: 60000
# Number of testing samples: 10000
# Number of classes: 10

# %% [markdown]
# ### Flatten the data to pass it into a dense network

# %%
X_train = np.reshape(x_train, (60000, 784))
X_test = np.reshape(x_test, (10000, 784))

print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %% [markdown]
# # Normalise the data by dividing by 255 - the max value

# %%
X_train = np.divide(X_train, 255)
X_test = np.divide(X_test, 255)

# %% [markdown]
# ### Create and train a tensorflow fully connected neural network on the training set

# %%
model = tf.keras.Sequential(layers=[
    tf.keras.layers.Dense(4, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.relu),
    tf.keras.layers.Dense(len(np.unique(X_train)), activation=tf.nn.softmax)])

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=tf.keras.metrics.SparseCategoricalAccuracy())

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 1500/1500 [==============================] - 1s 654us/step - loss: 3.4593 - sparse_categorical_accuracy: 0.1920 - val_loss: 0.8842 - val_sparse_categorical_accuracy: 0.6936
# Epoch 2/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.8122 - sparse_categorical_accuracy: 0.7270 - val_loss: 0.5997 - val_sparse_categorical_accuracy: 0.8177
# Epoch 3/100
# 1500/1500 [==============================] - 1s 596us/step - loss: 0.6340 - sparse_categorical_accuracy: 0.8040 - val_loss: 0.5523 - val_sparse_categorical_accuracy: 0.8351
# Epoch 4/100
# 1500/1500 [==============================] - 1s 597us/step - loss: 0.5906 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.5278 - val_sparse_categorical_accuracy: 0.8442
# Epoch 5/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.5592 - sparse_categorical_accuracy: 0.8381 - val_loss: 0.5058 - val_sparse_categorical_accuracy: 0.8514
# Epoch 6/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.5358 - sparse_categorical_accuracy: 0.8465 - val_loss: 0.5048 - val_sparse_categorical_accuracy: 0.8500
# Epoch 7/100
# 1500/1500 [==============================] - 1s 596us/step - loss: 0.5275 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.4832 - val_sparse_categorical_accuracy: 0.8556
# Epoch 8/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.5173 - sparse_categorical_accuracy: 0.8537 - val_loss: 0.4754 - val_sparse_categorical_accuracy: 0.8602
# Epoch 9/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.5040 - sparse_categorical_accuracy: 0.8562 - val_loss: 0.4705 - val_sparse_categorical_accuracy: 0.8617
# Epoch 10/100
# 1500/1500 [==============================] - 1s 595us/step - loss: 0.5046 - sparse_categorical_accuracy: 0.8536 - val_loss: 0.4642 - val_sparse_categorical_accuracy: 0.8662
# Epoch 11/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.4837 - sparse_categorical_accuracy: 0.8618 - val_loss: 0.4620 - val_sparse_categorical_accuracy: 0.8638
# Epoch 12/100
# 1500/1500 [==============================] - 1s 613us/step - loss: 0.4842 - sparse_categorical_accuracy: 0.8637 - val_loss: 0.4652 - val_sparse_categorical_accuracy: 0.8618
# Epoch 13/100
# 1500/1500 [==============================] - 1s 609us/step - loss: 0.4877 - sparse_categorical_accuracy: 0.8629 - val_loss: 0.4531 - val_sparse_categorical_accuracy: 0.8672
# Epoch 14/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4744 - sparse_categorical_accuracy: 0.8639 - val_loss: 0.4555 - val_sparse_categorical_accuracy: 0.8655
# Epoch 15/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.4606 - sparse_categorical_accuracy: 0.8674 - val_loss: 0.4440 - val_sparse_categorical_accuracy: 0.8680
# Epoch 16/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.4583 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.4377 - val_sparse_categorical_accuracy: 0.8738
# Epoch 17/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.4592 - sparse_categorical_accuracy: 0.8685 - val_loss: 0.4315 - val_sparse_categorical_accuracy: 0.8713
# Epoch 18/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.4463 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.4355 - val_sparse_categorical_accuracy: 0.8718
# Epoch 19/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4579 - sparse_categorical_accuracy: 0.8699 - val_loss: 0.4400 - val_sparse_categorical_accuracy: 0.8724
# Epoch 20/100
# 1500/1500 [==============================] - 1s 598us/step - loss: 0.4424 - sparse_categorical_accuracy: 0.8734 - val_loss: 0.4425 - val_sparse_categorical_accuracy: 0.8671
# Epoch 21/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.4232 - val_sparse_categorical_accuracy: 0.8753
# Epoch 22/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.4428 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.4280 - val_sparse_categorical_accuracy: 0.8728
# Epoch 23/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4414 - sparse_categorical_accuracy: 0.8754 - val_loss: 0.4216 - val_sparse_categorical_accuracy: 0.8758
# Epoch 24/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.4378 - sparse_categorical_accuracy: 0.8742 - val_loss: 0.4313 - val_sparse_categorical_accuracy: 0.8703
# Epoch 25/100
# 1500/1500 [==============================] - 1s 600us/step - loss: 0.4360 - sparse_categorical_accuracy: 0.8767 - val_loss: 0.4156 - val_sparse_categorical_accuracy: 0.8782
# Epoch 26/100
# 1500/1500 [==============================] - 1s 612us/step - loss: 0.4362 - sparse_categorical_accuracy: 0.8748 - val_loss: 0.4285 - val_sparse_categorical_accuracy: 0.8730
# Epoch 27/100
# 1500/1500 [==============================] - 1s 612us/step - loss: 0.4275 - sparse_categorical_accuracy: 0.8784 - val_loss: 0.4162 - val_sparse_categorical_accuracy: 0.8777
# Epoch 28/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.4240 - sparse_categorical_accuracy: 0.8804 - val_loss: 0.4181 - val_sparse_categorical_accuracy: 0.8763
# Epoch 29/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.4190 - sparse_categorical_accuracy: 0.8795 - val_loss: 0.4156 - val_sparse_categorical_accuracy: 0.8768
# Epoch 30/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.4166 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.4078 - val_sparse_categorical_accuracy: 0.8788
# Epoch 31/100
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4100 - sparse_categorical_accuracy: 0.8844 - val_loss: 0.4068 - val_sparse_categorical_accuracy: 0.8824
# Epoch 32/100
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.4161 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.4017 - val_sparse_categorical_accuracy: 0.8816
# Epoch 33/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.4159 - sparse_categorical_accuracy: 0.8814 - val_loss: 0.4041 - val_sparse_categorical_accuracy: 0.8830
# Epoch 34/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4117 - sparse_categorical_accuracy: 0.8831 - val_loss: 0.4153 - val_sparse_categorical_accuracy: 0.8763
# Epoch 35/100
# 1500/1500 [==============================] - 1s 596us/step - loss: 0.4191 - sparse_categorical_accuracy: 0.8792 - val_loss: 0.4265 - val_sparse_categorical_accuracy: 0.8747
# Epoch 36/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.4147 - sparse_categorical_accuracy: 0.8824 - val_loss: 0.3964 - val_sparse_categorical_accuracy: 0.8842
# Epoch 37/100
# 1500/1500 [==============================] - 1s 609us/step - loss: 0.4088 - sparse_categorical_accuracy: 0.8810 - val_loss: 0.3986 - val_sparse_categorical_accuracy: 0.8833
# Epoch 38/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.4133 - sparse_categorical_accuracy: 0.8820 - val_loss: 0.4026 - val_sparse_categorical_accuracy: 0.8837
# Epoch 39/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.4127 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.4052 - val_sparse_categorical_accuracy: 0.8808
# Epoch 40/100
# 1500/1500 [==============================] - 1s 610us/step - loss: 0.4135 - sparse_categorical_accuracy: 0.8815 - val_loss: 0.4100 - val_sparse_categorical_accuracy: 0.8823
# Epoch 41/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.4168 - sparse_categorical_accuracy: 0.8823 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.8802
# Epoch 42/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.4080 - sparse_categorical_accuracy: 0.8824 - val_loss: 0.4000 - val_sparse_categorical_accuracy: 0.8814
# Epoch 43/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.4131 - sparse_categorical_accuracy: 0.8812 - val_loss: 0.3978 - val_sparse_categorical_accuracy: 0.8842
# Epoch 44/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4060 - sparse_categorical_accuracy: 0.8852 - val_loss: 0.3927 - val_sparse_categorical_accuracy: 0.8855
# Epoch 45/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.3949 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3984 - val_sparse_categorical_accuracy: 0.8837
# Epoch 46/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.4015 - sparse_categorical_accuracy: 0.8827 - val_loss: 0.4048 - val_sparse_categorical_accuracy: 0.8804
# Epoch 47/100
# 1500/1500 [==============================] - 1s 595us/step - loss: 0.4028 - sparse_categorical_accuracy: 0.8842 - val_loss: 0.3947 - val_sparse_categorical_accuracy: 0.8840
# Epoch 48/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3936 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.3948 - val_sparse_categorical_accuracy: 0.8835
# Epoch 49/100
# 1500/1500 [==============================] - 1s 598us/step - loss: 0.3995 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3953 - val_sparse_categorical_accuracy: 0.8858
# Epoch 50/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4066 - sparse_categorical_accuracy: 0.8826 - val_loss: 0.3932 - val_sparse_categorical_accuracy: 0.8825
# Epoch 51/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.4054 - sparse_categorical_accuracy: 0.8841 - val_loss: 0.3938 - val_sparse_categorical_accuracy: 0.8844
# Epoch 52/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.3961 - sparse_categorical_accuracy: 0.8857 - val_loss: 0.3922 - val_sparse_categorical_accuracy: 0.8823
# Epoch 53/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.3937 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.8812
# Epoch 54/100
# 1500/1500 [==============================] - 1s 610us/step - loss: 0.4012 - sparse_categorical_accuracy: 0.8848 - val_loss: 0.3881 - val_sparse_categorical_accuracy: 0.8858
# Epoch 55/100
# 1500/1500 [==============================] - 1s 609us/step - loss: 0.4027 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.3880 - val_sparse_categorical_accuracy: 0.8852
# Epoch 56/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.3933 - sparse_categorical_accuracy: 0.8870 - val_loss: 0.3981 - val_sparse_categorical_accuracy: 0.8812
# Epoch 57/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.3858 - sparse_categorical_accuracy: 0.8886 - val_loss: 0.3936 - val_sparse_categorical_accuracy: 0.8842
# Epoch 58/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.3987 - sparse_categorical_accuracy: 0.8868 - val_loss: 0.4054 - val_sparse_categorical_accuracy: 0.8797
# Epoch 59/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.3923 - sparse_categorical_accuracy: 0.8856 - val_loss: 0.3998 - val_sparse_categorical_accuracy: 0.8821
# Epoch 60/100
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.3915 - sparse_categorical_accuracy: 0.8851 - val_loss: 0.3882 - val_sparse_categorical_accuracy: 0.8848
# Epoch 61/100
# 1500/1500 [==============================] - 1s 598us/step - loss: 0.3894 - sparse_categorical_accuracy: 0.8866 - val_loss: 0.4037 - val_sparse_categorical_accuracy: 0.8781
# Epoch 62/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.3994 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3962 - val_sparse_categorical_accuracy: 0.8809
# Epoch 63/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3949 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3999 - val_sparse_categorical_accuracy: 0.8804
# Epoch 64/100
# 1500/1500 [==============================] - 1s 598us/step - loss: 0.3862 - sparse_categorical_accuracy: 0.8858 - val_loss: 0.3918 - val_sparse_categorical_accuracy: 0.8852
# Epoch 65/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3777 - sparse_categorical_accuracy: 0.8916 - val_loss: 0.4023 - val_sparse_categorical_accuracy: 0.8812
# Epoch 66/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.3994 - sparse_categorical_accuracy: 0.8866 - val_loss: 0.3912 - val_sparse_categorical_accuracy: 0.8845
# Epoch 67/100
# 1500/1500 [==============================] - 1s 594us/step - loss: 0.3892 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3912 - val_sparse_categorical_accuracy: 0.8842
# Epoch 68/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.3849 - sparse_categorical_accuracy: 0.8875 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8842
# Epoch 69/100
# 1500/1500 [==============================] - 1s 604us/step - loss: 0.3823 - sparse_categorical_accuracy: 0.8890 - val_loss: 0.3940 - val_sparse_categorical_accuracy: 0.8844
# Epoch 70/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.3878 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.3853 - val_sparse_categorical_accuracy: 0.8845
# Epoch 71/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.3914 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.3845 - val_sparse_categorical_accuracy: 0.8872
# Epoch 72/100
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.3788 - sparse_categorical_accuracy: 0.8900 - val_loss: 0.3889 - val_sparse_categorical_accuracy: 0.8858
# Epoch 73/100
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.3839 - sparse_categorical_accuracy: 0.8891 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.8835
# Epoch 74/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.3915 - sparse_categorical_accuracy: 0.8890 - val_loss: 0.3838 - val_sparse_categorical_accuracy: 0.8878
# Epoch 75/100
# 1500/1500 [==============================] - 1s 597us/step - loss: 0.3783 - sparse_categorical_accuracy: 0.8909 - val_loss: 0.3921 - val_sparse_categorical_accuracy: 0.8835
# Epoch 76/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.3768 - sparse_categorical_accuracy: 0.8894 - val_loss: 0.3966 - val_sparse_categorical_accuracy: 0.8850
# Epoch 77/100
# 1500/1500 [==============================] - 1s 610us/step - loss: 0.3889 - sparse_categorical_accuracy: 0.8894 - val_loss: 0.3854 - val_sparse_categorical_accuracy: 0.8867
# Epoch 78/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.3817 - sparse_categorical_accuracy: 0.8892 - val_loss: 0.3840 - val_sparse_categorical_accuracy: 0.8873
# Epoch 79/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3848 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.4000 - val_sparse_categorical_accuracy: 0.8834
# Epoch 80/100
# 1500/1500 [==============================] - 1s 598us/step - loss: 0.3824 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.4038 - val_sparse_categorical_accuracy: 0.8752
# Epoch 81/100
# 1500/1500 [==============================] - 1s 596us/step - loss: 0.3811 - sparse_categorical_accuracy: 0.8902 - val_loss: 0.3894 - val_sparse_categorical_accuracy: 0.8844
# Epoch 82/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.3877 - val_sparse_categorical_accuracy: 0.8850
# Epoch 83/100
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.3912 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3844 - val_sparse_categorical_accuracy: 0.8878
# Epoch 84/100
# 1500/1500 [==============================] - 1s 609us/step - loss: 0.3880 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3818 - val_sparse_categorical_accuracy: 0.8892
# Epoch 85/100
# 1500/1500 [==============================] - 1s 613us/step - loss: 0.3778 - sparse_categorical_accuracy: 0.8891 - val_loss: 0.3848 - val_sparse_categorical_accuracy: 0.8838
# Epoch 86/100
# 1500/1500 [==============================] - 1s 609us/step - loss: 0.3917 - sparse_categorical_accuracy: 0.8878 - val_loss: 0.3888 - val_sparse_categorical_accuracy: 0.8853
# Epoch 87/100
# 1500/1500 [==============================] - 1s 610us/step - loss: 0.3829 - sparse_categorical_accuracy: 0.8888 - val_loss: 0.3874 - val_sparse_categorical_accuracy: 0.8857
# Epoch 88/100
# 1500/1500 [==============================] - 1s 625us/step - loss: 0.3830 - sparse_categorical_accuracy: 0.8867 - val_loss: 0.3928 - val_sparse_categorical_accuracy: 0.8840
# Epoch 89/100
# 1500/1500 [==============================] - 1s 612us/step - loss: 0.3879 - sparse_categorical_accuracy: 0.8879 - val_loss: 0.3852 - val_sparse_categorical_accuracy: 0.8874
# Epoch 90/100
# 1500/1500 [==============================] - 1s 600us/step - loss: 0.3821 - sparse_categorical_accuracy: 0.8884 - val_loss: 0.3890 - val_sparse_categorical_accuracy: 0.8857
# Epoch 91/100
# 1500/1500 [==============================] - 1s 602us/step - loss: 0.3847 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.3867 - val_sparse_categorical_accuracy: 0.8853
# Epoch 92/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.3811 - sparse_categorical_accuracy: 0.8905 - val_loss: 0.3999 - val_sparse_categorical_accuracy: 0.8778
# Epoch 93/100
# 1500/1500 [==============================] - 1s 616us/step - loss: 0.3852 - sparse_categorical_accuracy: 0.8889 - val_loss: 0.3875 - val_sparse_categorical_accuracy: 0.8852
# Epoch 94/100
# 1500/1500 [==============================] - 1s 597us/step - loss: 0.3847 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.3873 - val_sparse_categorical_accuracy: 0.8883
# Epoch 95/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.3817 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.3907 - val_sparse_categorical_accuracy: 0.8848
# Epoch 96/100
# 1500/1500 [==============================] - 1s 605us/step - loss: 0.3830 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3846 - val_sparse_categorical_accuracy: 0.8863
# Epoch 97/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.3771 - sparse_categorical_accuracy: 0.8897 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.8847
# Epoch 98/100
# 1500/1500 [==============================] - 1s 608us/step - loss: 0.3803 - sparse_categorical_accuracy: 0.8886 - val_loss: 0.3909 - val_sparse_categorical_accuracy: 0.8827
# Epoch 99/100
# 1500/1500 [==============================] - 1s 606us/step - loss: 0.3785 - sparse_categorical_accuracy: 0.8896 - val_loss: 0.3897 - val_sparse_categorical_accuracy: 0.8847
# Epoch 100/100
# 1500/1500 [==============================] - 1s 603us/step - loss: 0.3789 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.4011 - val_sparse_categorical_accuracy: 0.8841

# %% [markdown]
# # Predict Test Labels

# %%
model.predict(X_test)

# %% [markdown]
# ### Predict labels for testing set and check accurancy

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 4)                 3140
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                50
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               2816
# =================================================================
# Total params: 6,006
# Trainable params: 6,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = model.evaluate(XTst, model.predict(XTst))
print(results)

#print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')


#print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-9dc27a570a41> in <module>
# ----> 1 results = model.evaluate(XTst, model.predict(XTst))
#       2 print(results)
#       3
#       4 #print(f'Test set loss: {results[0]:0.2f}, test set accuracy: {results[1]*100:0.2f}%')
#       5
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2939     with self._lock:
#    2940       (graph_function,
# -> 2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3356               call_context_key in self._function_cache.missed):
#    3357             return self._define_function_with_shape_relaxation(
# -> 3358                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3278
#    3279     graph_function = self._create_graph_function(
# -> 3280         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3281     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3282
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py:1478 predict_function  *
#         return step_function(self, iterator)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py:1468 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py:1461 run_step  **
#         outputs = model.predict_step(data)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py:1434 predict_step
#         return self(x, training=False)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     c:\users\lizks\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:259 assert_input_compatibility
#         ' but received input with shape ' + display_shape(x.shape))
#
#     ValueError: Input 0 of layer sequential_6 is incompatible with the layer: expected axis -1 of input shape to have value 784 but received input with shape (None, 13)

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.scatter(X_test[:,0], X_test[:,1], c=y_test)
plt.ylabel('Feature Dimension 1')
plt.xlabel('Feature Dimension 0')
plt.title('Ground Truth')
plt.subplot(122)
plt.title('Predicted Labels')
plt.xlabel('Feature Dimension 0')
plt.scatter(X_test[:,0], X_test[:,1], c=np.argmax(model.predict(X_test), axis=1))
plt.show()

# %% [markdown]
# ### Plot models training curves

# %%
plt.figure(figsize=[10,5])
plt.subplot(121)
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy',
           'Validation Accuracy'])
plt.title('Accuracy Curves')

plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss',
           'Validation Loss'])
plt.title('Loss Curves')
plt.show()

# %% [markdown]
# ### Change hyper parameters

# %% [markdown]
# # 4.4 Convolutional Neural Network for Digit Recognition

# %% [markdown]
# ### Load original MNIST dataset
# (x_train, y_train), (x_test, y_test)

# %% [markdown]
# ### Expland the data to include a channel dimension for CNN. As images are greyscale add one additional axis in the last dimension of our data

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
cnn_train_x = np.expand_dims(x_train, axis=(3))
cnn_test_x = np.expand_dims(x_test, axis=(3))

# %%
print(cnn_train_x.shape)
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ### Normalise the data

# %%
cnn_train_x = np.divide(cnn_train_x, 255)
cnn_test_x = np.divide(cnn_test_x, 255)

# %% [markdown]
# ### Create and train a Tensorflow Convolutional Neural Network on the training set using Conv2D and pooling Layers

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %% [markdown]
# ###  Predict labels for the testing set and check accuracy

# %% [markdown]
# ### Plot models traing curves

# %% [markdown]
# # Task 4.5

# %% [markdown]
# # What makes a neural network a "Deep Learning" Model

# %% [markdown]
# The number of layers of neurons, increasing the number of hidden layers makes the model do more logistic regression functions - as each neuron performas a logisitic regression anaylsis on a different set of parameters, if you complete more hidden layers, more combinations of parameters have been checked for optimality.

# %% [markdown]
# # How do I make my neural network deeper? How do I make it wider?

# %% [markdown]
# To add depth, add more hidden layers. To add width add more neurons to each layer. Although it is a good idea to have a similar number of neurons in each layer as the number of neurons inputted at the start of the model.

# %% [markdown]
# # How do I train my models for longer

# %% [markdown]
# By adding layers and adding neurons.

# %% [markdown]
# # Why does running the methods numerous times result in different accuracy values

# %% [markdown]
# Each neuron can be given random starting parameters so there is a stochastic nature to NN.

# %% [markdown]
# # What hyperparameters are availbale to our models? What happens when we alter the penalty in the SVM or the optimisation strategy in the neural network?

# %% [markdown]
# We can use different kernels, different degrees, change the number of iterations, gamma (kernel coefficients), probability
